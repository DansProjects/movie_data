# %% [markdown]
# # Finding Similar Movies

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
movie_cols = ['movie_id', 'title']
movies = pd.read_csv("movies.dat", names=movie_cols, usecols=range(2), header=0, sep="::", engine='python')

ratings_cols = ['user_id', 'movie_id', 'rating']
ratings = pd.read_csv("ratings.dat", names=ratings_cols, usecols=range(3), header=0, sep="::", engine='python')

movie_ratings = pd.merge(movies, ratings, left_on="movie_id", right_on="movie_id")
movie_ratings.shape
# Out:
# (998131, 4)

# %%
movie_ratings.head(3)
# Out:
#    movie_id           title  user_id  rating
# 0         2  Jumanji (1995)       10       5
# 1         2  Jumanji (1995)       13       3
# 2         2  Jumanji (1995)       18       2

# %%
movieRatings = movie_ratings.pivot_table(index=['user_id'],columns=['title'],values='rating')
movieRatings.head()
# Out:
# title    $1,000,000 Duck (1971)  'Night Mother (1986)  \
# user_id
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# 5                           NaN                   NaN
#
# title    'Til There Was You (1997)  'burbs, The (1989)  \
# user_id
# 1                              NaN                 NaN
# 2                              NaN                 NaN
# 3                              NaN                 NaN
# 4                              NaN                 NaN
# 5                              NaN                 NaN
#
# title    ...And Justice for All (1979)  1-900 (1994)  \
# user_id
# 1                                  NaN           NaN
# 2                                  NaN           NaN
# 3                                  NaN           NaN
# 4                                  NaN           NaN
# 5                                  NaN           NaN
#
# title    10 Things I Hate About You (1999)  101 Dalmatians (1961)  \
# user_id
# 1                                      NaN                    NaN
# 2                                      NaN                    NaN
# 3                                      NaN                    NaN
# 4                                      NaN                    NaN
# 5                                      NaN                    NaN
#
# title    101 Dalmatians (1996)  12 Angry Men (1957)       ...         \
# user_id                                                   ...
# 1                          NaN                  NaN       ...
# 2                          NaN                  NaN       ...
# 3                          NaN                  NaN       ...
# 4                          NaN                  NaN       ...
# 5                          NaN                  NaN       ...
#
# title    Young Poisoner's Handbook, The (1995)  Young Sherlock Holmes (1985)  \
# user_id
# 1                                          NaN                           NaN
# 2                                          NaN                           NaN
# 3                                          NaN                           NaN
# 4                                          NaN                           NaN
# 5                                          NaN                           NaN
#
# title    Young and Innocent (1937)  Your Friends and Neighbors (1998)  \
# user_id
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# 5                              NaN                                NaN
#
# title    Zachariah (1971)  Zed & Two Noughts, A (1985)  Zero Effect (1998)  \
# user_id
# 1                     NaN                          NaN                 NaN
# 2                     NaN                          NaN                 NaN
# 3                     NaN                          NaN                 NaN
# 4                     NaN                          NaN                 NaN
# 5                     NaN                          NaN                 NaN
#
# title    Zero Kelvin (Kj�rlighetens kj�tere) (1995)  Zeus and Roxanne (1997)  \
# user_id
# 1                                               NaN                      NaN
# 2                                               NaN                      NaN
# 3                                               NaN                      NaN
# 4                                               NaN                      NaN
# 5                                               NaN                      NaN
#
# title    eXistenZ (1999)
# user_id
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
#
# [5 rows x 3705 columns]

# %%
corrMatrix = movieRatings.corr(method='pearson', min_periods=100)
corrMatrix.head()

# %%
favoriteMovieRatings = movieRatings['Saving Private Ryan (1998)']

# %%
# create correlations between Saving Private Ryan and all other movies in our data set
similarMovies = movieRatings.corrwith(favoriteMovieRatings)
similarMovies = similarMovies.dropna()
similarMovies_df = pd.DataFrame(similarMovies)
similarMovies_df.head()
# Out:
#                                       0
# title
# $1,000,000 Duck (1971)         0.069881
# 'Night Mother (1986)           0.167915
# 'Til There Was You (1997)      0.152794
# 'burbs, The (1989)             0.049999
# ...And Justice for All (1979)  0.248957

# %%
movieStats = movie_ratings.groupby('title').agg({'rating': [np.size, np.mean]})

# %% [markdown]
# Let's get rid of any movies rated by fewer than 600 people, and check the top-rated ones that are left:

# %%
popularMovies = movieStats['rating']['size'] >= 600
movieStats[popularMovies].sort_values([('rating', 'mean')], ascending=False)[:15]
# Out:
#                                                    rating
#                                                      size      mean
# title
# Seven Samurai (The Magnificent Seven) (Shichini...    628  4.560510
# Shawshank Redemption, The (1994)                     2227  4.554558
# Godfather, The (1972)                                2223  4.524966
# Close Shave, A (1995)                                 657  4.520548
# Usual Suspects, The (1995)                           1783  4.517106
# Schindler's List (1993)                              2304  4.510417
# Wrong Trousers, The (1993)                            882  4.507937
# Raiders of the Lost Ark (1981)                       2514  4.477725
# Rear Window (1954)                                   1050  4.476190
# Star Wars: Episode IV - A New Hope (1977)            2991  4.453694
# Dr. Strangelove or: How I Learned to Stop Worry...   1367  4.449890
# To Kill a Mockingbird (1962)                          928  4.425647
# Casablanca (1942)                                    1669  4.412822
# Sixth Sense, The (1999)                              2459  4.406263
# Lawrence of Arabia (1962)                             831  4.401925

# %% [markdown]
# ### Similar movies

# %%
# join movie stats and similarity dataframe on title
df = movieStats[popularMovies].join(pd.DataFrame(similarMovies, columns=['similarity']));
df.sort_values(['similarity'], ascending=False).head(15)
# Out:
#                                       (rating, size)  (rating, mean)  \
# title
# Saving Private Ryan (1998)                      2653        4.337354
# Forrest Gump (1994)                             2194        4.087967
# Schindler's List (1993)                         2304        4.510417
# Apollo 13 (1995)                                1251        4.073541
# Braveheart (1995)                               2443        4.234957
# Patton (1970)                                    645        4.266667
# Dances with Wolves (1990)                       1451        3.915231
# Green Mile, The (1999)                          1222        4.154664
# Ben-Hur (1959)                                   704        4.110795
# Bridge on the River Kwai, The (1957)             938        4.386994
# Jungle Book, The (1967)                          664        3.816265
# Right Stuff, The (1983)                          750        4.080000
# U-571 (2000)                                     908        3.539648
# Patriot, The (2000)                             1240        3.745161
# Glory (1989)                                    1112        4.193345
#
#                                       similarity
# title
# Saving Private Ryan (1998)              1.000000
# Forrest Gump (1994)                     0.363563
# Schindler's List (1993)                 0.343939
# Apollo 13 (1995)                        0.327342
# Braveheart (1995)                       0.304084
# Patton (1970)                           0.302743
# Dances with Wolves (1990)               0.298823
# Green Mile, The (1999)                  0.294570
# Ben-Hur (1959)                          0.287531
# Bridge on the River Kwai, The (1957)    0.287072
# Jungle Book, The (1967)                 0.285817
# Right Stuff, The (1983)                 0.280842
# U-571 (2000)                            0.279174
# Patriot, The (2000)                     0.272695
# Glory (1989)                            0.264111

# %% [markdown]
# And, sort these new results by similarity score. That's more like it!
